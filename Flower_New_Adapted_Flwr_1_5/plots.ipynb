-05), (28, 8.394552511163055e-05), (29, 6.093227118253708e-05), (30, 7.321180845610797e-05), (31, 6.733338965568691e-05), (32, 0.00011495346296578646), (33, 4.442437659599818e-05), (34, 0.0002230213260045275), (35, 6.0637308459263295e-05), (36, 0.0001654877217952162), (37, 0.00012386898801196365), (38, 9.189146663993597e-05), (39, 6.8711890198756e-05), (40, 8.826608851086349e-05), (41, 0.00019102260691579432), (42, 0.00021777634078171105), (43, 0.00010797055822331459), (44, 0.00035039327270351353), (45, 0.00036193435918539763), (46, 0.0002527620671316981), (47, 0.0008474964532069861), (48, 0.00020379660511389374), (49, 0.0003375329836271703), (50, 0.0004819813831709325), (51, 7.685039239004255e-05), (52, 0.0002920976977329701), (53, 0.00023830381594598294), (54, 0.00019399177993182092), (55, 0.00023770085722208024), (56, 0.0008504014099016786), (57, 0.0007892793882638216), (58, 0.0008557579126209021), (59, 0.0003955630315467715), (60, 0.0002675597816705704), (61, 0.0005366240171715617), (62, 0.0003259788455907255), (63, 0.0006249132109805942), (64, 0.0005688758357428014), (65, 0.0021604287885129453), (66, 0.0005128666879609227), (67, 0.0012311046551913023), (68, 0.0004852142669260502), (69, 0.000725578360259533), (70, 0.0004454107149504125), (71, 0.0010418632458895445), (72, 0.0005565379853360355), (73, 0.0002788394601084292), (74, 0.0014978678021579982), (75, 0.000386896762996912), (76, 0.0004587065703235567), (77, 0.0008555439407937228), (78, 0.0004661951046437025), (79, 0.0012418183777481318), (80, 0.0006584916058927774), (81, 0.0013401141976937651), (82, 0.0008672501174733043), (83, 0.0004948492106050253), (84, 0.0013004379849880935), (85, 0.0011739211902022362), (86, 0.0011735259369015693), (87, 0.0007269158791750669), (88, 0.000544352535624057), (89, 0.0008863107771612704), (90, 0.0006084735915064812), (91, 0.001011809067800641), (92, 0.0010852399338036776), (93, 0.0030671985782682897), (94, 0.0010236734338104725), (95, 0.0013485291730612517), (96, 0.0009890709044411779), (97, 0.0024493439178913832), (98, 0.001711418926715851), (99, 0.0007768293912522495), (100, 0.0013073649192228913)]}
import matplotlib.pyplot as plt
import numpy as np
client_ids=[0,1]

plt.figure(figsize=(15, 5 * len(client_ids)))

# Loop over each client's saved metrics for plotting
for idx, client_id in enumerate(client_ids):
    # Load data from npy files
    losses = np.load(f'client_{client_id}_losses.npy')
    dice_coefs = np.load(f'client_{client_id}_dice_coefs.npy')
    soft_dice_coefs = np.load(f'client_{client_id}_soft_dice_coefs.npy')
    
    losses = [100.0 * data for data in losses]
    dice_coefs = [100.0 * data for data in dice_coefs]
    soft_dice_coefs = [100.0 * data for data in soft_dice_coefs]


    # Plotting Loss for the client
    plt.subplot(len(client_ids), 3, idx * 3 + 1)
    plt.plot(losses, label=f'Client {client_id} Loss')
    plt.title(f'Client {client_id} Loss over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Loss')
    plt.xticks(range(0,len(losses)+10,10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

    # Plotting Dice Coefficient for the client
    plt.subplot(len(client_ids), 3, idx * 3 + 2)
    plt.plot(dice_coefs, label=f'Client {client_id} Dice Coefficient')
    plt.title(f'Client {client_id} Dice Coefficient over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Dice Coefficient')
    plt.xticks(range(0,len(dice_coefs)+10,10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

    # Plotting Soft Dice Coefficient for the client
    plt.subplot(len(client_ids), 3, idx * 3 + 3)
    plt.plot(soft_dice_coefs, label=f'Client {client_id} Soft Dice Coefficient')
    plt.title(f'Client {client_id} Soft Dice Coefficient over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Soft Dice Coefficient')
    plt.xticks(range(0, len(soft_dice_coefs)+10, 10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Read in the .npy files from Flower_New_Adapted_Flwr_1_5 directory
import numpy as np
import matplotlib.pyplot as plt

for client_id in range(0,2):
    plt.figure(figsize=(15, 5 * 2))
    idx=client_id
    print(id)
    losses = np.load(f'Plots/X_client_{client_id}_losses.npy')
    dice_coefs = np.load(f'Plots/X_client_{client_id}_dice_coefs.npy')
    soft_dice_coefs = np.load(f'Plots/X_client_{client_id}_soft_dice_coefs.npy')
    losses = [100.0 * data for data in losses]
    dice_coefs = [100.0 * data for data in dice_coefs]
    soft_dice_coefs = [100.0 * data for data in soft_dice_coefs]

    # Plotting Loss for the client
    plt.subplot(2, 3, idx * 3 + 1)
    plt.plot(losses, label=f'Client {client_id} Loss')
    plt.title(f'Client {client_id} Loss over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Loss')
    plt.xticks(range(0,len(losses)+10,10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

    # Plotting Dice Coefficient for the client
    plt.subplot(2, 3, idx * 3 + 2)
    plt.plot(dice_coefs, label=f'Client {client_id} Dice Coefficient')
    plt.title(f'Client {client_id} Dice Coefficient over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Dice Coefficient (%)')
    plt.xticks(range(0,len(dice_coefs)+10,10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

    # Plotting Soft Dice Coefficient for the client
    plt.subplot(2, 3, idx * 3 + 3)
    plt.plot(soft_dice_coefs, label=f'Client {client_id} Soft Dice Coefficient')
    plt.title(f'Client {client_id} Soft Dice Coefficient over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel('Soft Dice Coefficient (%)')
    plt.xticks(range(0,len(soft_dice_coefs)+10,10))
    # plt.ylim(0, 100)  # set y-axis range to 0-100
    plt.legend()

    # Adjust layout and display the plots
    plt.tight_layout()
    plt.savefig(f'Plots/X_2_clients_plots_FedAvg_client_{client_id}.png')
    # plt.show()
    plt.figure()
# Out:
# <built-in function id>
# <built-in function id>
