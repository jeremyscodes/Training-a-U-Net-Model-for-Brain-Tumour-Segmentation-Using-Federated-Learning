# %%
# 
import matplotlib.pyplot as plt
iou_coef_centralized_2_client= [(0, 1.194678400651128e-08), (1, 4.238363260355982e-08), (2, 9.037995596372639e-08), (3, 1.2671395666075114e-07), (4, 3.504600272208336e-07), (5, 4.2363726038274763e-07), (6, 4.5880796051278594e-07), (7, 4.988581849829643e-07), (8, 6.096962579249521e-07), (9, 5.318913736118702e-07), (10, 7.880614134592179e-07), (11, 7.312690968319657e-07), (12, 9.034762342707836e-07), (13, 1.1548897873581154e-06), (14, 2.2593026187678333e-06), (15, 3.83771021006396e-06), (16, 3.7673839869967196e-06), (17, 1.0470123015693389e-05), (18, 2.7123856852995232e-05), (19, 4.396164877107367e-05), (20, 7.184110290836543e-05), (21, 7.729507342446595e-05), (22, 0.5200066566467285), (23, 0.6800082921981812), (24, 0.5500059127807617), (25, 0.6200066208839417), (26, 0.9900010228157043), (27, 0.8500081896781921), (28, 0.5300041437149048), (29, 0.5500071048736572), (30, 0.5700071454048157), (31, 1.0), (32, 0.8800055384635925), (33, 0.5600064992904663), (34, 1.0), (35, 0.8700087666511536), (36, 0.82001131772995), (37, 1.0), (38, 0.530002772808075), (39, 1.0), (40, 0.8900035619735718), (41, 0.9600021243095398), (42, 0.9600013494491577), (43, 0.850003719329834), (44, 0.8400052189826965), (45, 0.9900010228157043), (46, 1.0), (47, 0.9700021743774414), (48, 0.9100041389465332), (49, 0.9700010418891907), (50, 0.9400032758712769), (51, 0.9500014185905457), (52, 0.7100058794021606), (53, 0.8300032615661621), (54, 0.9800013303756714), (55, 0.8500052690505981), (56, 0.8400017023086548), (57, 0.7400059700012207), (58, 0.8200028538703918), (59, 0.9700006246566772), (60, 0.960002601146698), (61, 1.0), (62, 1.0), (63, 1.0), (64, 1.0), (65, 1.0), (66, 0.780002772808075), (67, 0.720007598400116), (68, 0.7600046396255493), (69, 0.9500030279159546), (70, 0.7700021862983704), (71, 0.8100026845932007), (72, 1.0), (73, 0.9900010228157043), (74, 0.970002293586731), (75, 0.810001015663147), (76, 0.8800042867660522), (77, 0.8100017309188843), (78, 0.8400023579597473), (79, 0.8100022077560425), (80, 0.8100005984306335), (81, 0.9700003862380981), (82, 0.9500001668930054), (83, 0.8300021886825562), (84, 0.6700044274330139), (85, 0.9800010919570923), (86, 0.7200037837028503), (87, 0.6600059866905212), (88, 0.750003457069397), (89, 0.7800006866455078), (90, 0.9400001764297485), (91, 0.9200021028518677), (92, 0.9400001764297485), (93, 0.8300045728683472), (94, 0.870003879070282), (95, 0.940000057220459), (96, 0.7600030899047852), (97, 0.940000057220459), (98, 0.9100011587142944), (99, 0.9800010919570923), (100, 0.9200003743171692), (101, 0.9400013089179993), (102, 0.9400001764297485), (103, 0.9400001764297485), (104, 0.9400004148483276), (105, 0.8900030851364136), (106, 0.7400047183036804), (107, 0.940000057220459), (108, 0.9100014567375183), (109, 0.7200018763542175), (110, 0.8300010561943054), (111, 0.8000015020370483), (112, 0.8900014758110046), (113, 0.5700041055679321), (114, 0.850003719329834), (115, 0.8400020599365234), (116, 0.9100005030632019), (117, 0.9100006818771362), (118, 0.8100043535232544), (119, 0.7500036954879761), (120, 0.8900022506713867), (121, 0.7000014185905457), (122, 0.9200006723403931), (123, 0.8800026178359985), (124, 0.9300010800361633), (125, 0.9400003552436829), (126, 0.9200002551078796), (127, 0.960000216960907), (128, 0.940000057220459), (129, 0.9400002360343933), (130, 0.9200002551078796), (131, 0.8000032305717468), (132, 0.7300016283988953), (133, 0.9100010991096497), (134, 0.9200016260147095), (135, 0.9000006914138794), (136, 0.7400025129318237), (137, 0.9200003743171692), (138, 0.8900006413459778), (139, 0.8600037693977356), (140, 0.8000036478042603), (141, 0.8900012969970703), (142, 0.7800014615058899), (143, 0.6900020837783813), (144, 0.9100006818771362), (145, 0.8500025868415833), (146, 0.7100010514259338), (147, 0.9100021123886108), (148, 0.8600033521652222), (149, 0.7800019383430481), (150, 0.910000205039978), (151, 0.7500020265579224), (152, 0.6800012588500977), (153, 0.890001654624939), (154, 0.7700015902519226), (155, 0.9300006031990051), (156, 0.9200013875961304), (157, 0.9500007629394531), (158, 0.9300001859664917), (159, 0.9400002360343933), (160, 0.9400001764297485), (161, 0.9400004148483276), (162, 0.8700011968612671), (163, 0.8000008463859558), (164, 0.8800016641616821), (165, 0.8500028848648071), (166, 0.8300029635429382), (167, 0.8500038981437683), (168, 0.7800003886222839), (169, 0.910000205039978), (170, 0.8900005221366882), (171, 0.8600015640258789), (172, 0.850001335144043), (173, 0.910000205039978), (174, 0.8400008082389832), (175, 0.8600012063980103), (176, 0.8800023198127747), (177, 0.920000433921814), (178, 0.9100009202957153), (179, 0.9000005722045898), (180, 0.8900009393692017), (181, 0.7800025939941406), (182, 0.910000205039978), (183, 0.910000205039978), (184, 0.910000205039978), (185, 0.9200011491775513), (186, 0.8900007009506226), (187, 0.910000205039978), (188, 0.9100004434585571), (189, 0.9200006723403931), (190, 0.9100004434585571), (191, 0.910000205039978), (192, 0.910000205039978), (193, 0.910000205039978), (194, 0.7300009727478027), (195, 0.8500016927719116), (196, 0.910000205039978), (197, 0.9400001764297485), (198, 0.900002121925354), (199, 0.8700031042098999), (200, 0.8700021505355835)]
# plot iou
plt.plot(*zip(*iou_coef_centralized_2_client))
plt.title('IOU')
plt.xlabel('Round')
plt.ylabel('Validation IOU')
# plt.show()
plt.savefig('Final_Plots/iou_centralized_2_clients.png')

# %%
main = '..\\..\\My_Results\\'
cen_dir = 'Centralized_U-Net\\Final_Unet_Res\\raw_data'
fl_dir = 'Federated_U-Net\\'
dir2 = '2_Clients_Full_train\\raw_data'
dir4 = '4_Clients_Full_train\\raw_data'
dir_8 = '8_Clients_Full_train\\raw_data'

import matplotlib.pyplot as plt
import numpy as np


import numpy as np
import matplotlib.pyplot as plt


def plot_metrics_from_npys(metric_name, legend_names, colors, *file_paths, y_min=None,central=False, log_scale=False):
    if len(legend_names) != len(file_paths) or len(colors) != len(file_paths):
        raise ValueError("The number of legend names and colors must match the number of numpy arrays.")
    
    plt.figure(figsize=(10, 6))

    # Plot the last model's metrics first
    data_last = np.load(file_paths[-1], allow_pickle=True)
    rounds_last = [entry[0] for entry in data_last]
    metric_last = [100.0 * entry[1] if metric_name != 'Loss' else entry[1] for entry in data_last]
    line_last, = plt.plot(rounds_last, metric_last, color=colors[-1], label=legend_names[-1])
    
    # Plot the rest of the models' metrics
    lines = []
    for file_path, legend_name, color in zip(file_paths[:-1], legend_names[:-1], colors[:-1]):
        data = np.load(file_path, allow_pickle=True)
        rounds = [entry[0] for entry in data]


        if 'Centralized Model' == legend_name:
            if central:
                #rounds = num elements in data[0]
                print("Length ",len(data[:,0]))
                # rounds equals np.arrange 0 to len(data[0])
                rounds = np.arange(0,len(data[:,0]))
                
                metric_train = [100.0 * value  if metric_name != 'Loss' else value for value in data[:, 0]]
                metric_val = [100.0 * value  if metric_name != 'Loss' else value for value in data[:, 1]]
                line_train, = plt.plot(rounds, metric_train, color="orange", label=legend_name + ' (Train)')
                line_val, = plt.plot(rounds, metric_val, color="blue", label=legend_name + ' (Validation)')
                lines.extend([line_train, line_val])
        else:
            metric = [100.0 * entry[1] if metric_name != 'Loss' else entry[1] for entry in data]
            line, = plt.plot(rounds, metric, color=color, label=legend_name)  # using color_train just for simplicity
            lines.append(line)
    if y_min is not None:
        current_ylim = plt.ylim()
        plt.ylim(y_min, current_ylim[1])
    plt.grid()
    if metric_name == 'Loss':
        plt.ylabel(metric_name)
    else:
        plt.ylabel(metric_name + " (%)")
    plt.xlabel("Round")
    plt.title(f"Comparative Analysis of Validation {metric_name}")
    if log_scale:
        plt.yscale('log')
    # Manually specify the order of legend entries
    plt.legend(handles=lines + [line_last])  # append the last model's handle to the end
    # plt.show()
    plt.savefig(main+'\\Final_Plots\\Combined_log_' + metric_name + '.png')

# Usage:
# legend_names = ['Centralized Model', 'Federated (2 Clients)', 'Federated (4 Clients)', 'Federated (8 Clients)']
# colors = ['blue', 'red', 'green', 'purple']
# plot_metrics_from_npys('Accuracy', legend_names, colors, 'path_to_file1.npy', 'path_to_file2.npy', ...)


# Usage:
legend_names = ['Centralized Model', 'Federated (2 Clients)', 'Federated (4 Clients)', 'Federated (8 Clients)']
colors = ['blue', '#00FF00', '#9932CC', 'grey']
cen = main + cen_dir + "\\dice_coef.npy"

fl_2 = main + fl_dir + dir2 + "\\M_global_model_DC_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_DC_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_DC_8_clients_FedAvg.npy"
plot_metrics_from_npys('Dice Coefficient', legend_names, colors, cen, fl_2, fl_4, fl_8, central=True)


# # Example usage:
# plot_metric_from_npy(central_metric_path, 2, "metric Coefficient")
# path = main_dir + dir2 + "\\P_global_model_softDC_2_clients_FedAvg.npy"
# plot_metric_from_npy(path, 2, "Seft Dice Coefficient")


# central_loss_path = main_dir + dir2 + "\\P_global_model_loss_2_clients_FedAvg.npy"
# plot_metric_from_npy(central_loss_path, 2, "Loss")
# Out:
# Length  40

# %%
cen = main + cen_dir + "\\accuracy.npy"
metric = "Accuracy"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('Accuracy', legend_names, colors, cen, fl_2, fl_4, fl_8)

# %%
cen = main + cen_dir + "\\iou.npy"
metric = "IOU"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('IOU', legend_names, colors, cen, fl_2, fl_4, fl_8)

# %%
cen = main + cen_dir + "\\precision.npy"
metric = "Precision"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('Precision', legend_names, colors, cen, fl_2, fl_4, fl_8)

# %%
cen = main + cen_dir + "\\soft_dice_coef.npy"
metric = "softDC"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('Soft Dice', legend_names, colors, cen, fl_2, fl_4, fl_8, central=True, log_scale=True)
# Out:
# Length  40

# %%
cen = main + cen_dir + "\\specificity.npy"
metric = "Specificity"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('Precision', legend_names, colors, cen, fl_2, fl_4, fl_8)

# %%
cen = main + cen_dir + "\\loss.npy"
metric = "loss"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys('Loss', legend_names, colors, cen, fl_2, fl_4, fl_8,y_min=0,central=True)
# Out:
# Length  40

# %% [markdown]
# ## Centralized plots ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

def plot_and_save_from_npy(output_path, metric_names, label_names):
    # Define the save_plot function from your provided code
    def save_plot(values, val_values, ylabel, title, filename):
        metric = [100.0 * entry if metric_name != 'loss' else entry for entry in values]
        val_values = [100.0 * entry if metric_name != 'loss' else entry for entry in val_values]
        plt.figure(figsize=(10, 6))
        if metric_name != 'loss':
            plt.ylim(0, 100)
    
        plt.plot(metric)
        plt.plot(val_values)
        plt.title(title)
        plt.ylabel(ylabel)
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='lower right')
        try:
            # plt.show()
            plt.savefig(main+'\\Final_Plots\\Central_Model_' + metric_name + '.png')
        except Exception as e:
            print(f"Error saving plot {filename}: {e}")
        finally:
            plt.close()
    
    # For each metric, load the .npy file and plot
    for i,metric_name in enumerate(metric_names):
        try:
            data = np.load(os.path.join(output_path, f'{metric_name}.npy'))
            train_values = data[:, 0]
            val_values = data[:, 1]
            save_plot(train_values, val_values, label_names[i], f'Centralized Model {metric_name}', 
                      os.path.join(output_path, f'Central_{metric_name}_plot.png'))
        except Exception as e:
            print(f"Error plotting and saving {metric_name}: {e}")

# Usage
metric_names = ['loss', 'dice_coef', 'soft_dice_coef', 'precision', 'accuracy', 'specificity', 'iou']
label_names = ['Loss', 'Dice', 'Soft Dice', 'Precision', 'Accuracy', 'Specificity', 'IOU']
cen = main + cen_dir
plot_and_save_from_npy(cen, metric_names, label_names)

# %% [markdown]
# # Client plots #

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_metrics_from_clients(metric_name, file_paths_list, labels, output_path, colors=None):
    """
    Plots metrics from multiple FL models on the same graph.

    Args:
    - metric_name (str): Name of the metric (e.g., 'loss', 'dice_coef').
    - file_paths_list (list of lists): Each inner list contains file paths for a specific FL model.
    - labels (list): List of labels for the FL models.
    - output_path (str): Directory to save the combined plot.
    - colors (list, optional): List of colors for the plots. Defaults to None.
    """

    plt.figure(figsize=(10, 6))
    
    if colors is None:
        colors = plt.cm.jet(np.linspace(0, 1, len(labels)))

    for file_paths, label, color in zip(file_paths_list, labels, colors):
        all_metrics = []
        for file_path in file_paths:
            metrics = np.load(file_path)
            all_metrics.append(np.mean(metrics) * 100)  # Assuming metrics are in range [0, 1]
        
        plt.plot(all_metrics, label=label, color=color)

    plt.title(f'{metric_name} over Rounds')
    plt.xlabel('Rounds')
    plt.ylabel(f'{metric_name} (%)')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(output_path, f'{metric_name}_combined_plot.png'))
    plt.close()
    
loss_paths_list =[ ['A_FLFedAvg_8_client_1_losses.npy', 'A_FLFedAvg_8_client_2_losses.npy', 'A_FLFedAvg_8_client_3_losses.npy', 'A_FLFedAvg_8_client_4_losses.npy', 'A_FLFedAvg_8_client_5_losses.npy', 'A_FLFedAvg_8_client_6_losses.npy', 'A_FLFedAvg_8_client_7_losses.npy', 'A_FLFedAvg_8_client_8_losses.npy'],
 
 ['A_FLFedAvg_8_client_1_dice_coefs.npy', 'A_FLFedAvg_8_client_2_dice_coefs.npy', 'A_FLFedAvg_8_client_3_dice_coefs.npy', 'A_FLFedAvg_8_client_4_dice_coefs.npy', 'A_FLFedAvg_8_client_5_dice_coefs.npy', 'A_FLFedAvg_8_client_6_dice_coefs.npy', 'A_FLFedAvg_8_client_7_dice_coefs.npy', 'A_FLFedAvg_8_client_8_dice_coefs.npy'],
 
 ['A_FLFedAvg_8_client_1_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_2_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_3_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_4_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_5_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_6_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_7_soft_dice_coefs.npy', 'A_FLFedAvg_8_client_8_soft_dice_coefs.npy'],
 
 ['A_FLFedAvg_8_client_1_iou.npy', 'A_FLFedAvg_8_client_2_iou.npy', 'A_FLFedAvg_8_client_3_iou.npy', 'A_FLFedAvg_8_client_4_iou.npy', 'A_FLFedAvg_8_client_5_iou.npy', 'A_FLFedAvg_8_client_6_iou.npy', 'A_FLFedAvg_8_client_7_iou.npy', 'A_FLFedAvg_8_client_8_iou.npy']
]


labels = ['FL Model 1', 'FL Model 2']  # ... add more labels for other FL models

colors = ['red', 'blue']  # ... add more colors for other FL models

plot_metrics_from_clients('loss', loss_paths_list, labels, 'path_to_output_directory', colors)

# %% [markdown]
# ## Moving averages losses ##

# %%
main_dir = '..\\..\\My_Results\\Federated_U-Net\\'
dir2 = '2_Clients_Full_train\\raw_data'
dir4 = '4_Clients_Full_train\\raw_data'
dir_8 = '8_Clients_Full_train\\raw_data'

import os
import matplotlib.pyplot as plt
import numpy as np
central_loss_path = main_dir + dir2 + "\\P_global_model_loss_2_clients_FedAvg.npy"

import numpy as np
import matplotlib.pyplot as plt

def moving_average(data, window_size):
    """Compute the moving average of the data."""
    cumsum = np.cumsum(data)
    cumsum[window_size:] = cumsum[window_size:] - cumsum[:-window_size]
    return cumsum[window_size - 1:] / window_size
def moving_average2(data, window_size):
    """Compute the moving average of the data with central alignment."""
    half_window = window_size // 2
    result = []
    
    for i in range(len(data)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(data), i + half_window + (window_size % 2))
        
        avg_value = np.mean(data[start_idx:end_idx])
        result.append(avg_value)
    
    return result


def plot_metric_from_npy(file_path, num_clients, metric_name, window_size=2):
    # Load data from the .npy file
    data = np.load(file_path, allow_pickle=True)

    # Extract rounds and dice coefficients
    rounds = [entry[0] for entry in data]
    if metric_name != 'Loss':
        metric = [100.0 * entry[1] for entry in data]
    else: metric = [entry[1] for entry in data]

    # Compute the moving average if window_size > 1
    if window_size > 1:
        metric = moving_average(metric, window_size)
        rounds = rounds[window_size-1:]  # Adjust rounds to match the length of the smoothed metric

    # Plot the data
    plt.figure()
    plt.plot(rounds, metric)
    plt.grid()
    plt.ylabel(metric_name+" (%)")
    plt.xlabel("Round")
    plt.title(f"Aggregated model's {metric_name} with {num_clients} clients (Window size: {window_size})")
    plt.show()

# Example usage:
# plot_dice_from_npy('path_to_file.npy', 10, 'Dice Coefficient', window_size=5)


# Example usage:
plot_metric_from_npy(central_loss_path, 2, "Loss", window_size=1)

plot_metric_from_npy(central_loss_path, 2, "Loss", window_size=5)
plot_metric_from_npy(central_loss_path, 2, "Loss", window_size=10)

central_loss_4_clients = main_dir + dir4 + "\\A_global_model_loss_4_clients_FedAvg.npy"
plot_metric_from_npy(central_loss_4_clients, 4, "Loss", window_size=1)
plot_metric_from_npy(central_loss_4_clients, 4, "Loss", window_size=10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12572/1657845301.py in <module>
#      61
#      62 # Example usage:
# ---> 63 plot_metric_from_npy(central_loss_path, 2, "Loss", window_size=1)
#      64
#      65 plot_metric_from_npy(central_loss_path, 2, "Loss", window_size=5)
#
# ~\AppData\Local\Temp/ipykernel_12572/1657845301.py in plot_metric_from_npy(file_path, num_clients, metric_name, window_size)
#      34 def plot_metric_from_npy(file_path, num_clients, metric_name, window_size=2):
#      35     # Load data from the .npy file
# ---> 36     data = np.load(file_path, allow_pickle=True)
#      37
#      38     # Extract rounds and dice coefficients
#
# c:\Users\jerem\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405             own_fid = False
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def moving_average(data, window_size):
    """Compute the moving average of the data."""
    cumsum = np.cumsum(data)
    cumsum[window_size:] = cumsum[window_size:] - cumsum[:-window_size]
    return cumsum[window_size - 1:] / window_size

def plot_metrics_from_npys_moving_ave(metric_name, legend_names, colors, *file_paths, y_min=None, central=False, window_size=2):
    if len(legend_names) != len(file_paths) or len(colors) != len(file_paths):
        raise ValueError("The number of legend names and colors must match the number of numpy arrays.")
    
    plt.figure(figsize=(10, 6))

    # Plot the last model's metrics first
    data_last = np.load(file_paths[-1], allow_pickle=True)
    rounds_last = [entry[0] for entry in data_last]
    metric_last = [100.0 * entry[1] if metric_name != 'Loss' else entry[1] for entry in data_last]
    if window_size > 1 and 'Centralized Model' != legend_names[-1]:  # Apply moving average if it's a federated model
        metric_last = moving_average(metric_last, window_size)
        rounds_last = rounds_last[window_size-1:]
    line_last, = plt.plot(rounds_last, metric_last, color=colors[-1], label=legend_names[-1])
    
    # Plot the rest of the models' metrics
    lines = []
    for file_path, legend_name, color in zip(file_paths[:-1], legend_names[:-1], colors[:-1]):
        data = np.load(file_path, allow_pickle=True)
        rounds = [entry[0] for entry in data]
        metric = [100.0 * entry[1] if metric_name != 'Loss' else entry[1] for entry in data]
        if window_size > 1 and 'Centralized Model' != legend_name:  # Apply moving average if it's a federated model
            metric = moving_average(metric, window_size)
            rounds = rounds[window_size-1:]
        
        if 'Centralized Model' == legend_name and central:
            print("Length ",len(data[:,0]))
            rounds = np.arange(0,len(data[:,0]))
            metric_train = [100.0 * value  if metric_name != 'Loss' else value for value in data[:, 0]]
            metric_val = [100.0 * value  if metric_name != 'Loss' else value for value in data[:, 1]]
            line_train, = plt.plot(rounds, metric_train, color="orange", label=legend_name + ' (Train)')
            line_val, = plt.plot(rounds, metric_val, color="blue", label=legend_name + ' (Validation)')
            lines.extend([line_train, line_val])
        else:
            line, = plt.plot(rounds, metric, color=color, label=legend_name)
            lines.append(line)
    
    if y_min is not None:
        current_ylim = plt.ylim()
        plt.ylim(y_min, current_ylim[1])
    plt.grid()
    if metric_name == 'Loss':
        plt.ylabel(metric_name)
    else:
        plt.ylabel(metric_name + " (%)")
    plt.xlabel("Round")
    plt.title(f"Comparative Analysis of Validation {metric_name} with Moving Average")
    plt.legend(handles=lines + [line_last])
    plt.savefig(main+'\\Final_Plots\\Federated_' + metric_name + 'averaged.png')

# Example usage:
# plot_metrics_from_npys('Loss', ['Model 1', 'Model 2'], ['red', 'blue'], 'path_to_file1.npy', 'path_to_file2.npy', window_size=5)
cen = main + cen_dir + "\\loss.npy"
metric = "loss"
fl_2 = main + fl_dir + dir2 + "\\M_global_model_"+metric+"_2_clients_FedAvg.npy"
fl_4 = main + fl_dir + dir4 + "\\A_global_model_"+metric+"_4_clients_FedAvg.npy"
fl_8 = main + fl_dir + dir_8 + "\\I_global_model_"+metric+"_8_clients_FedAvg.npy"
plot_metrics_from_npys_moving_ave('Loss', legend_names, colors, cen, fl_2, fl_4, fl_8,y_min=0,central=True, window_size=10)
# Out:
# Length  40

# %% [markdown]
# ### Combined Client Plots ###

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_clients_metrics(main, fl_dir, dir2, dir4, dir8, metrics, metric_titles):
    fl_setups = [2, 4, 8]
    fl_characters = ['M','A','I']
    dir_list = [dir2, dir4, dir8]
    
    for metric, title in zip(metrics,metric_titles):
        for letter, fl_setup, directory in zip(fl_characters, fl_setups, dir_list):
            plt.figure(figsize=(10, 6))
            for client_id in range(fl_setup):
                file_path = f"{main}{fl_dir}{directory}\\{letter}_FLFedAvg_{fl_setup}_client_{client_id}_{metric}.npy"
                data = np.load(file_path, allow_pickle=True)
                rounds = np.arange(len(data))  # Create an array [0, 1, 2, ..., len(data)-1]
                if title =='Loss':
                    metric_values = [entry for entry in data]
                else:
                    metric_values = [entry*100 for entry in data]
                plt.plot(rounds, metric_values, label=f'Client {client_id}')
            
            plt.grid()
            plt.ylabel(title)
            plt.xlabel('Round')
            plt.title(f'{fl_setup}-Client Setup - {title}')
            plt.legend()
            plt.savefig(f"{main}\\Final_Plots\\{fl_setup}_Client_{title}.png")
            plt.show()

# Set up the directories and metrics
main = '..\\..\\My_Results\\'
fl_dir = 'Federated_U-Net\\'
dir2 = '2_Clients_Full_train\\raw_data'
dir4 = '4_Clients_Full_train\\raw_data'
dir8 = '8_Clients_Full_train\\raw_data'
metrics = ['losses', 'dice_coefs', 'soft_dice_coefs']
metric_titles=['Loss','Dice Coefficient','Soft Dice Coefficient']

# Call the function to plot the metrics
plot_clients_metrics(main, fl_dir, dir2, dir4, dir8, metrics, metric_titles)

# %% [markdown]
# ### Check for data leak ###

# %%
import pandas as pd

# test_files = pd.read_csv('test_file_paths.csv')
# train_files = pd.read_csv('train_file_paths.csv')

test_files_mod = pd.read_csv('test_file_paths_clean.csv')
train_files_mod = pd.read_csv('train_file_paths_clean.csv')

print(test_files_mod.head()) 
print(train_files_mod.head())

duplicate=False
for i in range(len(test_files_mod)):
    if test_files_mod.iloc[i,0] in train_files_mod.iloc[:,0]:
        print(test_files_mod.iloc[i,0])
        print('Error')
        duplicate=True
if not duplicate:
    print('No duplicate files in train and test sets')
# Out:
#                             path
# 0  ././imagesTr/BRATS_350.nii.gz
# 1  ././imagesTr/BRATS_378.nii.gz
# 2  ././imagesTr/BRATS_346.nii.gz
# 3  ././imagesTr/BRATS_442.nii.gz
# 4  ././imagesTr/BRATS_266.nii.gz
#                             path
# 0  ././imagesTr/BRATS_089.nii.gz
# 1  ././imagesTr/BRATS_071.nii.gz
# 2  ././imagesTr/BRATS_183.nii.gz
# 3  ././imagesTr/BRATS_046.nii.gz
# 4  ././imagesTr/BRATS_182.nii.gz
# No duplicate files in train and test sets
